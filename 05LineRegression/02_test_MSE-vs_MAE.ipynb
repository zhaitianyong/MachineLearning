# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import datasets

# %% [markdown]
# # 波士顿房产数据预测，只选择其中一个维度

# %%
boston = datasets.load_boston()

# %%
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
x = boston.data[:,5]
y = boston.target

x.shape, y.shape
# Out:
# ((506,), (506,))

# %%
plt.scatter(x, y)
plt.show()

# %%
np.max(y)
# Out:
# 50.0

# %%
x = x[ y < 50.0]
y = y[ y < 50.0]

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# # 运行自定义的Module

# %%
import sys
sys.path.append(r"C:\Users\atway\Desktop\DL\MachineLearning")

# %%
from myML.metrics import r2_score
from myML.SimpleLinearRegression import SimpleLinearRegression

# %%
reg = SimpleLinearRegression()
a, b = reg.fit(x, y)
y_predict = reg.predict(x)

# %%
plt.scatter(x, y)
plt.plot(x, y_predict, color='r')
plt.show()

# %%
r2 = r2_score(y, y_predict)
r2
# Out:
# 0.47146668144517589

# %%
import myML.metrics as metrics

# %%
metrics.root_mean_square_error(y, y_predict)
# Out:
# 5.712259460556422

# %%
metrics.mean_absolute_error(y, y_predict)
# Out:
# 4.1108370989454235
